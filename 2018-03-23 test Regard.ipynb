# %% [markdown]
# # Training settings

# %%
# %run Regard.py --epochs 1 --log-interval 0
# Out:
# cuda? False
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/research/Shared/2018-03-19_StageL3/anaisbrgs_StageL3/Regard.py in <module>()
#     157         t0 = time.time () # ajout de la constante de temps t0
#     158
# --> 159         main()
#     160
#     161         t1 = time.time () # ajout de la constante de temps t1
#
# ~/research/Shared/2018-03-19_StageL3/anaisbrgs_StageL3/Regard.py in main()
#     142 def main():
#     143     for epoch in range(1, args.epochs + 1):
# --> 144         train(epoch)
#     145         Accuracy = test()
#     146     print('Test set: Final Accuracy: {:.3f}%'.format(Accuracy*100)) # print que le pourcentage de réussite final
#
# ~/research/Shared/2018-03-19_StageL3/anaisbrgs_StageL3/Regard.py in train(epoch)
#     106         data, target = Variable(data).long(), Variable(target).long()
#     107         optimizer.zero_grad()
# ...

# %%
# %run pytorch_finetune.py --train_dir dataset --val_dir dataset
# Out:
# /usr/local/lib/python3.6/site-packages/torchvision/transforms/transforms.py:156: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
# /usr/local/lib/python3.6/site-packages/torchvision/transforms/transforms.py:397: UserWarning: The use of the transforms.RandomSizedCrop transform is deprecated, please use transforms.RandomResizedCrop instead.
#   "please use transforms.RandomResizedCrop instead.")
# Starting epoch 1 / 10
# Train accuracy:  0.35368956743002544
# Val accuracy:  0.35368956743002544
#
# Starting epoch 2 / 10
# Train accuracy:  0.34096692111959287
# Val accuracy:  0.3333333333333333
#
# Starting epoch 3 / 10
# Train accuracy:  0.35877862595419846
# Val accuracy:  0.3333333333333333
#
# Starting epoch 4 / 10
# Train accuracy:  0.3842239185750636
# Val accuracy:  0.356234096692112
#
# Starting epoch 5 / 10
# Train accuracy:  0.37404580152671757
# ...

# %%
# %run pytorch_finetune.py --train_dir dataset --val_dir dataset --num_epochs1 100 --num_epochs2 100
# Out:
# /usr/local/lib/python3.6/site-packages/torchvision/transforms/transforms.py:156: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
# /usr/local/lib/python3.6/site-packages/torchvision/transforms/transforms.py:397: UserWarning: The use of the transforms.RandomSizedCrop transform is deprecated, please use transforms.RandomResizedCrop instead.
#   "please use transforms.RandomResizedCrop instead.")
# Starting epoch 1 / 100
# Train accuracy:  0.3460559796437659
# Val accuracy:  0.33078880407124683
#
# Starting epoch 2 / 100
# Train accuracy:  0.3435114503816794
# Val accuracy:  0.3511450381679389
#
# Starting epoch 3 / 100
# Train accuracy:  0.36895674300254455
# Val accuracy:  0.37404580152671757
#
# Starting epoch 4 / 100
# Train accuracy:  0.3791348600508906
# Val accuracy:  0.40458015267175573
#
# Starting epoch 5 / 100
# Train accuracy:  0.3816793893129771
# ...

# %%
# %whos
# Out:
# Variable         Type                Data/Info
# ----------------------------------------------
# DataLoader       type                <class 'torch.utils.data.dataloader.DataLoader'>
# F                module              <module 'torch.nn.functio<...>/torch/nn/functional.py'>
# IMAGENET_MEAN    list                n=3
# IMAGENET_STD     list                n=3
# ImageFolder      type                <class 'torchvision.datasets.folder.ImageFolder'>
# Net              type                <class '__main__.Net'>
# T                module              <module 'torchvision.tran<...>/transforms/__init__.py'>
# Variable         type                <class 'torch.autograd.variable.Variable'>
# argparse         module              <module 'argparse' from '<...>b/python3.6/argparse.py'>
# args             Namespace           Namespace(batch_size=32, <...>False, val_dir='dataset')
# autopep8         module              <module 'autopep8' from '<...>te-packages/autopep8.py'>
# ...
